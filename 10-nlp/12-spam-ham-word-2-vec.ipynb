# %% [markdown]
# Spam ham using word 2 vec using gensim

# %%
import gensim
from gensim.models import Word2Vec,KeyedVectors
# importing gensim library and word2vec model

# %%
import gensim.downloader as api   
wv=api.load('word2vec-google-news-300')
# this is using pretrained model of google news 300
# using specific word to vec using api function

# after this we will make w3v from scratch

# %%
vec_king=wv['king']
vec_king
# word 2 vec for king
# Out:
# array([ 1.25976562e-01,  2.97851562e-02,  8.60595703e-03,  1.39648438e-01,
#        -2.56347656e-02, -3.61328125e-02,  1.11816406e-01, -1.98242188e-01,
#         5.12695312e-02,  3.63281250e-01, -2.42187500e-01, -3.02734375e-01,
#        -1.77734375e-01, -2.49023438e-02, -1.67968750e-01, -1.69921875e-01,
#         3.46679688e-02,  5.21850586e-03,  4.63867188e-02,  1.28906250e-01,
#         1.36718750e-01,  1.12792969e-01,  5.95703125e-02,  1.36718750e-01,
#         1.01074219e-01, -1.76757812e-01, -2.51953125e-01,  5.98144531e-02,
#         3.41796875e-01, -3.11279297e-02,  1.04492188e-01,  6.17675781e-02,
#         1.24511719e-01,  4.00390625e-01, -3.22265625e-01,  8.39843750e-02,
#         3.90625000e-02,  5.85937500e-03,  7.03125000e-02,  1.72851562e-01,
#         1.38671875e-01, -2.31445312e-01,  2.83203125e-01,  1.42578125e-01,
#         3.41796875e-01, -2.39257812e-02, -1.09863281e-01,  3.32031250e-02,
# ...

# %%
# importing datset of spam collection    

import pandas as pd
messages=pd.read_csv(r"D:\maths-naik\code_ml\SMSSpamCollection",sep='\t',names=['label','message'])

# %%
messages.head()
# Out:
#   label                                            message
# 0   ham  Go until jurong point, crazy.. Available only ...
# 1   ham                      Ok lar... Joking wif u oni...
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3   ham  U dun say so early hor... U c already then say...
# 4   ham  Nah I don't think he goes to usf, he lives aro...

# %%
# using lammatisation instead of stemming

from nltk.stem import WordNetLemmatizer
lemmatiser=WordNetLemmatizer()

# %%
# re is used to remove unwanted characters
import re  
import nltk

# %%
corpus=[]

# one change we made is not removing stop words

for i in range(len(messages)):
    review=re.sub('[^a-zA-Z]',' ',messages['message'][i])
    review=review.lower()
    review=review.split()
    review=[lemmatiser.lemmatize(word) for word in review ]
    review=' '.join(review)
    corpus.append(review)

# %%
corpus

# this is lammatised corpus
# Out:
# ['go until jurong point crazy available only in bugis n great world la e buffet cine there got amore wat',
#  'ok lar joking wif u oni',
#  'free entry in a wkly comp to win fa cup final tkts st may text fa to to receive entry question std txt rate t c s apply over s',
#  'u dun say so early hor u c already then say',
#  'nah i don t think he go to usf he life around here though',
#  'freemsg hey there darling it s been week s now and no word back i d like some fun you up for it still tb ok xxx std chgs to send to rcv',
#  'even my brother is not like to speak with me they treat me like aid patent',
#  'a per your request melle melle oru minnaminunginte nurungu vettam ha been set a your callertune for all caller press to copy your friend callertune',
#  'winner a a valued network customer you have been selected to receivea prize reward to claim call claim code kl valid hour only',
# ...

# %%
# tokenisation for sentences and word
# and simple preprocess is specific technique of gensim
from nltk  import sent_tokenize,word_tokenize
from gensim.utils import simple_preprocess

# %%
# another way of doing this stemmiing or lammatise

words_altway=[]

for sent in corpus:
    # first tokenise the sentences in corpus
    sent_token=sent_tokenize(sent)
    for sent in sent_token:
        words_altway.append(simple_preprocess(sent))
        # this simple_preprocess will remove the punctuation and

# %%
print(words)
# Out:
# [['go', 'until', 'jurong', 'point', 'crazy', 'available', 'only', 'in', 'bugis', 'great', 'world', 'la', 'buffet', 'cine', 'there', 'got', 'amore', 'wat'], ['ok', 'lar', 'joking', 'wif', 'oni'], ['free', 'entry', 'in', 'wkly', 'comp', 'to', 'win', 'fa', 'cup', 'final', 'tkts', 'st', 'may', 'text', 'fa', 'to', 'to', 'receive', 'entry', 'question', 'std', 'txt', 'rate', 'apply', 'over'], ['dun', 'say', 'so', 'early', 'hor', 'already', 'then', 'say'], ['nah', 'don', 'think', 'he', 'go', 'to', 'usf', 'he', 'life', 'around', 'here', 'though'], ['freemsg', 'hey', 'there', 'darling', 'it', 'been', 'week', 'now', 'and', 'no', 'word', 'back', 'like', 'some', 'fun', 'you', 'up', 'for', 'it', 'still', 'tb', 'ok', 'xxx', 'std', 'chgs', 'to', 'send', 'to', 'rcv'], ['even', 'my', 'brother', 'is', 'not', 'like', 'to', 'speak', 'with', 'me', 'they', 'treat', 'me', 'like', 'aid', 'patent'], ['per', 'your', 'request', 'melle', 'melle', 'oru', 'minnaminunginte', 'nurungu', 'vettam', 'ha', 'been', 'set'
# ...

# %%
print(words_altway)
# Out:
# [['go', 'until', 'jurong', 'point', 'crazy', 'available', 'only', 'in', 'bugis', 'great', 'world', 'la', 'buffet', 'cine', 'there', 'got', 'amore', 'wat'], ['ok', 'lar', 'joking', 'wif', 'oni'], ['free', 'entry', 'in', 'wkly', 'comp', 'to', 'win', 'fa', 'cup', 'final', 'tkts', 'st', 'may', 'text', 'fa', 'to', 'to', 'receive', 'entry', 'question', 'std', 'txt', 'rate', 'apply', 'over'], ['dun', 'say', 'so', 'early', 'hor', 'already', 'then', 'say'], ['nah', 'don', 'think', 'he', 'go', 'to', 'usf', 'he', 'life', 'around', 'here', 'though'], ['freemsg', 'hey', 'there', 'darling', 'it', 'been', 'week', 'now', 'and', 'no', 'word', 'back', 'like', 'some', 'fun', 'you', 'up', 'for', 'it', 'still', 'tb', 'ok', 'xxx', 'std', 'chgs', 'to', 'send', 'to', 'rcv'], ['even', 'my', 'brother', 'is', 'not', 'like', 'to', 'speak', 'with', 'me', 'they', 'treat', 'me', 'like', 'aid', 'patent'], ['per', 'your', 'request', 'melle', 'melle', 'oru', 'minnaminunginte', 'nurungu', 'vettam', 'ha', 'been', 'set'
# ...

# %%
import gensim
from gensim.models import Word2Vec

# %%
# lets train word2vec from scratch using gensim taking the words list
model=gensim.models.Word2Vec(words_altway)

# %%
# import gensim.downloader as api   
# wv=api.load('word2vec-google-news-300')

# %%
model.wv.index_to_key
# Out:
# ['to',
#  'you',
#  'the',
#  'it',
#  'and',
#  'in',
#  'is',
#  'me',
#  'my',
#  'for',
#  'your',
#  'call',
#  'of',
#  'that',
#  'have',
#  'on',
#  'now',
#  'are',
#  'can',
#  'so',
#  'but',
#  'not',
#  'or',
#  'we',
#  'do',
#  'get',
#  'at',
#  'ur',
#  'will',
#  'if',
#  'be',
#  'with',
#  'no',
#  'just',
#  'this',
#  'gt',
#  'lt',
#  'go',
#  'how',
#  'up',
#  'when',
#  'ok',
#  'day',
#  'what',
#  'free',
#  'from',
#  'all',
#  'out',
#  'know',
#  'll',
#  'come',
#  'like',
#  'good',
#  'time',
#  'am',
#  'then',
#  'got',
#  'wa',
#  'there',
#  'he',
#  'love',
#  'text',
#  'only',
#  'want',
#  'send',
#  'one',
#  'need',
#  'txt',
#  'today',
#  'by',
#  'going',
#  'don',
#  'stop',
#  'home',
#  'she',
#  'about',
#  'lor',
#  'sorry',
#  'see',
#  'still',
#  'mobile',
#  'take',
#  'back',
#  'da',
#  'reply',
#  'dont',
#  'our',
#  'think',
#  'tell',
#  'week',
#  'hi',
#  'phone',
#  'they',
#  'new',
#  'please',
#  'later',
#  'pls',
# ...

# %%
model.corpus_count
# Out:
# 5569

# %%
model.epochs
# Out:
# 5

# %%
model.wv.similar_by_word("happy")
# Out:
# [('day', 0.9991456270217896),
#  ('great', 0.9989128708839417),
#  ('my', 0.9988536238670349),
#  ('dear', 0.9988163113594055),
#  ('hey', 0.9987832903862),
#  ('hope', 0.9987691640853882),
#  ('wish', 0.9987691044807434),
#  ('of', 0.99872887134552),
#  ('nice', 0.9987097978591919),
#  ('well', 0.9987096786499023)]

# %%
model.wv['good'].shape
# Out:
# (100,)

# %%
words[0]
# this 1st sentence has so many words and we can make one vector 
# for all these words
# also for every word there is 100 dim vectors (default value)
# so we can take average of all the vectors only 1 100 dim vector
#make average word2 vec and take one vector for whole sentence
# Out:
# ['go',
#  'until',
#  'jurong',
#  'point',
#  'crazy',
#  'available',
#  'only',
#  'in',
#  'bugis',
#  'great',
#  'world',
#  'la',
#  'buffet',
#  'cine',
#  'there',
#  'got',
#  'amore',
#  'wat']

# %%
# this is a function to take average of all the word2vec for a sentence
def avg_word2vec(doc):  
    return np.mean([model.wv[word] for word in doc if word in model.wv.index_to_key])

# %%
# !pip install tqdm

# %%
from tqdm import tqdm

# %%
import numpy as np

# %%
x=[]
for i in tqdm(range(len(words_altway))):
    x.append(avg_word2vec(words_altway[i]))
# Out:
#   0%|          | 0/5569 [00:00<?, ?it/s]c:\Users\nande\anaconda3\envs\ml_env\Lib\site-packages\numpy\core\fromnumeric.py:3504: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# c:\Users\nande\anaconda3\envs\ml_env\Lib\site-packages\numpy\core\_methods.py:129: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# 100%|██████████| 5569/5569 [00:00<00:00, 10160.09it/s]

# %%
len(x)
# Out:
# 5569

# %%
messages.shape
# Out:
# (5572, 2)

# %%
x_new=np.array(x)
#indpendent features

# %%
x_new[0].shape
# Out:
# ()

# %%
y=messages[list(map(lambda x:len(x)>0,corpus))]
y=pd.get_dummies(y['label'],dtype=int)
y=y.iloc[:,1].values
y
# Out:
# array([0, 0, 1, ..., 0, 0, 0])
