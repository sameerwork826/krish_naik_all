# %%
# Step 1: Import Libraries and Load the Model
import numpy as np
import tensorflow as tf
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence
from tensorflow.keras.models import load_model

# %%
# Load the IMDB dataset word index
word_index = imdb.get_word_index()
reverse_word_index = {value: key for key, value in word_index.items()}

# %%
# Load the pre-trained model with ReLU activation
model = load_model('simple_rnn_imdb.h5')
model.summary()
# Out:
# c:\Users\nande\anaconda3\envs\ml_env\Lib\site-packages\keras\src\layers\core\embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# c:\Users\nande\anaconda3\envs\ml_env\Lib\site-packages\keras\src\layers\core\embedding.py:100: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Load the pre-trained model with ReLU activation
# ----> 2 model = load_model('simple_rnn_imdb.h5')
#       3 model.summary()
#
# File c:\Users\nande\anaconda3\envs\ml_env\Lib\site-packages\keras\src\saving\saving_api.py:196, in load_model(filepath, custom_objects, compile, safe_mode)
#     189     return saving_lib.load_model(
#     190         filepath,
#     191         custom_objects=custom_objects,
#     192         compile=compile,
#     193         safe_mode=safe_mode,
#     194     )
#     195 if str(filepath).endswith((".h5", ".hdf5")):
# --> 196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath, custom_objects=custom_objects, compile=compile
#     198     )
#     199 elif str(filepath).endswith(".keras"):
#     200     raise ValueError(
#     201         f"File not found: filepath={filepath}. "
#     202         "Please ensure the file is an accessible `.keras` "
#     203         "zip file."
#     204     )
#
# File c:\Users\nande\anaconda3\envs\ml_env\Lib\site-packages\keras\src\legacy\saving\legacy_h5_format.py:133, in load_model_from_hdf5(filepath, custom_objects, compile)
#     130 model_config = json_utils.decode(model_config)
#     132 with saving_options.keras_option_scope(use_legacy_config=True):
# --> 133     model = saving_utils.model_from_config(
#     134         model_config, custom_objects=custom_objects
#     135     )
#     137     # set weights
#     138     load_weights_from_hdf5_group(f["model_weights"], model)
#
# File c:\Users\nande\anaconda3\envs\ml_env\Lib\site-packages\keras\src\legacy\saving\saving_utils.py:88, in model_from_config(config, custom_objects)
#      84 # TODO(nkovela): Swap find and replace args during Keras 3.0 release
#      85 # Replace keras refs with keras
#      86 config = _find_replace_nested_dict(config, "keras.", "keras.")
# ---> 88 return serialization.deserialize_keras_object(
#      89     config,
#      90     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      91     custom_objects=custom_objects,
#      92     printable_module_name="layer",
#      93 )
#
# File c:\Users\nande\anaconda3\envs\ml_env\Lib\site-packages\keras\src\legacy\saving\serialization.py:495, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     490 cls_config = _find_replace_nested_dict(
#     491     cls_config, "keras.", "keras."
#     492 )
#     494 if "custom_objects" in arg_spec.args:
# --> 495     deserialized_obj = cls.from_config(
#     496         cls_config,
#     497         custom_objects={
#     498             **object_registration.GLOBAL_CUSTOM_OBJECTS,
#     499             **custom_objects,
#     500         },
#     501     )
#     502 else:
#     503     with object_registration.CustomObjectScope(custom_objects):
#
# File c:\Users\nande\anaconda3\envs\ml_env\Lib\site-packages\keras\src\models\sequential.py:366, in Sequential.from_config(cls, config, custom_objects)
#     362 for layer_config in layer_configs:
#     363     if "module" not in layer_config:
#     364         # Legacy format deserialization (no "module" key)
#     365         # used for H5 and SavedModel formats
# --> 366         layer = saving_utils.model_from_config(
#     367             layer_config,
#     368             custom_objects=custom_objects,
#     369         )
#     370     else:
#     371         layer = serialization_lib.deserialize_keras_object(
#     372             layer_config,
#     373             custom_objects=custom_objects,
#     374         )
#
# File c:\Users\nande\anaconda3\envs\ml_env\Lib\site-packages\keras\src\legacy\saving\saving_utils.py:88, in model_from_config(config, custom_objects)
#      84 # TODO(nkovela): Swap find and replace args during Keras 3.0 release
#      85 # Replace keras refs with keras
#      86 config = _find_replace_nested_dict(config, "keras.", "keras.")
# ---> 88 return serialization.deserialize_keras_object(
#      89     config,
#      90     module_objects=MODULE_OBJECTS.ALL_OBJECTS,
#      91     custom_objects=custom_objects,
#      92     printable_module_name="layer",
#      93 )
#
# File c:\Users\nande\anaconda3\envs\ml_env\Lib\site-packages\keras\src\legacy\saving\serialization.py:504, in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     502     else:
#     503         with object_registration.CustomObjectScope(custom_objects):
# --> 504             deserialized_obj = cls.from_config(cls_config)
#     505 else:
#     506     # Then `cls` may be a function returning a class.
#     507     # in this case by convention `config` holds
#     508     # the kwargs of the function.
#     509     custom_objects = custom_objects or {}
#
# File c:\Users\nande\anaconda3\envs\ml_env\Lib\site-packages\keras\src\layers\rnn\simple_rnn.py:449, in SimpleRNN.from_config(cls, config)
#     447 @classmethod
#     448 def from_config(cls, config):
# --> 449     return cls(**config)
#
# File c:\Users\nande\anaconda3\envs\ml_env\Lib\site-packages\keras\src\layers\rnn\simple_rnn.py:341, in SimpleRNN.__init__(self, units, activation, use_bias, kernel_initializer, recurrent_initializer, bias_initializer, kernel_regularizer, recurrent_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, recurrent_constraint, bias_constraint, dropout, recurrent_dropout, return_sequences, return_state, go_backwards, stateful, unroll, seed, **kwargs)
#     296 def __init__(
#     297     self,
#     298     units,
#    (...)
#     319     **kwargs,
#     320 ):
#     321     cell = SimpleRNNCell(
#     322         units,
#     323         activation=activation,
#    (...)
#     339         name="simple_rnn_cell",
#     340     )
# --> 341     super().__init__(
#     342         cell,
#     343         return_sequences=return_sequences,
#     344         return_state=return_state,
#     345         go_backwards=go_backwards,
#     346         stateful=stateful,
#     347         unroll=unroll,
#     348         **kwargs,
#     349     )
#     350     self.input_spec = [InputSpec(ndim=3)]
#
# File c:\Users\nande\anaconda3\envs\ml_env\Lib\site-packages\keras\src\layers\rnn\rnn.py:199, in RNN.__init__(self, cell, return_sequences, return_state, go_backwards, stateful, unroll, zero_output_for_mask, **kwargs)
#     192 if "state_size" not in dir(cell):
#     193     raise ValueError(
#     194         "The RNN cell should have a `state_size` attribute "
#     195         "(single integer or list of integers, "
#     196         "one integer per RNN state). "
#     197         f"Received: cell={cell}"
#     198     )
# --> 199 super().__init__(**kwargs)
#     201 # If True, the output for masked timestep will be zeros, whereas in the
#     202 # False case, output from previous timestep is returned for masked
#     203 # timestep.
#     204 self.zero_output_for_mask = zero_output_for_mask
#
# File c:\Users\nande\anaconda3\envs\ml_env\Lib\site-packages\keras\src\layers\layer.py:291, in Layer.__init__(self, activity_regularizer, trainable, dtype, autocast, name, **kwargs)
#     289     self._input_shape_arg = input_shape_arg
#     290 if kwargs:
# --> 291     raise ValueError(
#     292         "Unrecognized keyword arguments "
#     293         f"passed to {self.__class__.__name__}: {kwargs}"
#     294     )
#     296 self._path = None  # Will be determined in `build_wrapper`
#     297 self.built = False
#
# ValueError: Unrecognized keyword arguments passed to SimpleRNN: {'time_major': False}

# %%
model.get_weights()
# Out:
# [array([[ 0.01294318,  0.00555024, -0.07671961, ..., -0.01263755,
#           0.00505546,  0.02497914],
#         [ 0.00844798, -0.02933332, -0.00715619, ..., -0.00862716,
#           0.00665992,  0.05880589],
#         [-0.05171771, -0.0432808 , -0.08375057, ..., -0.02969957,
#           0.01567038,  0.00068079],
#         ...,
#         [ 0.09266458, -0.08101614,  0.04658744, ...,  0.01804913,
#          -0.17538679,  0.00067434],
#         [ 0.01653318,  0.06926119,  0.0049732 , ...,  0.04035291,
#           0.09395951, -0.1132597 ],
#         [ 0.1440855 ,  0.00126064,  0.32376543, ...,  0.0426919 ,
#           0.02079754, -0.18269144]], dtype=float32),
#  array([[-0.12330135,  0.08859511,  0.05113527, ...,  0.03298575,
#           0.17755416,  0.01216303],
#         [-0.04188077, -0.04186596, -0.08071131, ...,  0.15609226,
#          -0.07695719,  0.02690291],
#         [-0.00996152, -0.11690302, -0.03616346, ...,  0.05564096,
#           0.10746004,  0.16173892],
#         ...,
#         [-0.04128347, -0.12895729, -0.04160175, ...,  0.10292391,
#          -0.11404378,  0.11960836],
#         [-0.13437633,  0.13250333,  0.048429  , ...,  0.12124723,
#           0.09109742,  0.03739859],
#         [ 0.00612393, -0.07154756, -0.10596388, ...,  0.03549517,
#          -0.08537208, -0.11219272]], dtype=float32),
#  array([[-0.05019443, -0.15970261,  0.06620254, ...,  0.01478922,
#          -0.20160072, -0.00200535],
#         [ 0.02547389, -0.14232425,  0.10224531, ...,  0.05960698,
#           0.03495593, -0.08410195],
#         [-0.08031869,  0.01449137, -0.15939988, ...,  0.13432762,
#          -0.03014112, -0.14351478],
#         ...,
#         [ 0.09908138, -0.02558508, -0.13526438, ...,  0.14588276,
#           0.10193573, -0.06331481],
#         [-0.013219  ,  0.02056809, -0.14330292, ..., -0.09014762,
#          -0.03742609, -0.09928254],
#         [ 0.00200558, -0.12337051, -0.08651818, ..., -0.01134081,
#           0.12214413, -0.10153519]], dtype=float32),
#  array([-0.02309091, -0.03741068,  0.03608138, -0.01012204, -0.00961697,
#         -0.04460302, -0.00890457, -0.07695267,  0.01861246, -0.06464651,
#         -0.08086395, -0.01328344,  0.00105586, -0.02800237, -0.01785051,
#         -0.00622015, -0.02442832, -0.02629573,  0.02212375, -0.01550421,
#          0.05668161, -0.02439414, -0.03024566, -0.0371494 ,  0.02734491,
#          0.0137857 ,  0.01077526,  0.04795163,  0.0565894 , -0.04734827,
#          0.01955677, -0.05873004, -0.07976162, -0.01395048, -0.02731251,
#         -0.05969859,  0.03336314, -0.03217271, -0.01740261,  0.04155161,
#          0.06053625, -0.0171354 ,  0.00052911, -0.05854859, -0.0450738 ,
#         -0.0253187 ,  0.00143284, -0.01905231, -0.02248414,  0.01698363,
#          0.05048538, -0.07089506, -0.01799666, -0.01236872,  0.00720825,
#         -0.06968991, -0.00735683, -0.03576791, -0.03235625,  0.01668187,
#         -0.0124646 , -0.03585856, -0.01481889, -0.01683425, -0.03364329,
#          0.00830212, -0.05432278, -0.01847805, -0.02533711,  0.01218841,
#         -0.00347905, -0.03700072,  0.05948552, -0.02471007,  0.04226987,
#         -0.02998188, -0.03084427, -0.02242245,  0.03180672, -0.05690002,
#         -0.0411725 , -0.01928658, -0.01843143, -0.01586537, -0.01968092,
#          0.00390431,  0.00076472, -0.04312361, -0.0709859 , -0.02491646,
#          0.02453926, -0.0479385 , -0.05013692, -0.07256468,  0.00988924,
#         -0.04044138,  0.04704519,  0.0196924 , -0.0672816 , -0.03375299,
#         -0.04270802,  0.03169771,  0.01201228, -0.05631541, -0.03496821,
#         -0.06590761, -0.00964317, -0.1062262 , -0.08234407, -0.01456998,
#          0.01616633, -0.00447171, -0.03786589,  0.02508426,  0.00992819,
#         -0.05261707, -0.05102415,  0.03502916, -0.07364725, -0.0755309 ,
#          0.00502022, -0.05057528, -0.00859022, -0.05067655, -0.00985054,
#         -0.04826203, -0.01846999, -0.04007601], dtype=float32),
#  array([[ 0.11595645],
#         [-0.00529686],
#         [-0.05457472],
#         [ 0.01470216],
#         [ 0.20000954],
#         [-0.13846892],
#         [-0.18157549],
#         [-0.23629507],
#         [-0.02878064],
#         [ 0.17259157],
#         [ 0.18896657],
#         [ 0.07424159],
#         [-0.77745426],
#         [ 0.08186729],
#         [ 0.30792058],
#         [-0.12810759],
#         [ 0.23312101],
#         [ 0.22137557],
#         [ 0.03697284],
#         [ 0.24465637],
#         [-0.1167772 ],
#         [ 0.04021973],
#         [-0.4232067 ],
#         [ 0.08432519],
#         [-0.42301178],
#         [-0.21174248],
#         [ 0.0091623 ],
#         [ 0.32204092],
#         [ 0.06027399],
#         [-0.38956913],
#         [ 0.09338259],
#         [ 0.11900039],
#         [ 0.14020142],
#         [-0.1894668 ],
#         [ 0.07855153],
#         [-0.01872942],
#         [ 0.07324233],
#         [-0.09990288],
#         [ 0.16306993],
#         [-0.06781595],
#         [-0.25271928],
#         [ 0.03868847],
#         [ 0.04550266],
#         [ 0.25156492],
#         [-0.24850017],
#         [ 0.0506701 ],
#         [-0.08674552],
#         [ 0.07844183],
#         [-0.11809575],
#         [-1.07241   ],
#         [-0.11071204],
#         [-0.11617515],
#         [ 0.1282895 ],
#         [ 0.08715433],
#         [ 0.29407784],
#         [ 0.2475507 ],
#         [ 0.1541417 ],
#         [-0.09103858],
#         [ 0.20693782],
#         [ 0.40929618],
#         [-0.10386249],
#         [ 0.60727894],
#         [-0.21770532],
#         [ 0.00134858],
#         [-0.01836918],
#         [-0.28639016],
#         [ 0.1954314 ],
#         [-0.07684585],
#         [ 0.11209404],
#         [-0.13845737],
#         [ 0.15810429],
#         [ 0.13746333],
#         [ 0.13304867],
#         [-0.32522362],
#         [-0.26805222],
#         [-0.09487963],
#         [-0.16901308],
#         [-0.07467802],
#         [-0.11366487],
#         [ 0.11139264],
#         [-0.17294426],
#         [ 0.1224246 ],
#         [ 0.00496355],
#         [ 0.22212194],
#         [ 0.5897257 ],
#         [ 0.28230628],
#         [ 0.08044104],
#         [-0.14508456],
#         [-0.20262592],
#         [ 0.13783379],
#         [ 0.13892034],
#         [ 0.15576725],
#         [ 0.21659467],
#         [ 0.15442413],
#         [ 0.03371518],
#         [-0.24519666],
#         [-0.1543945 ],
#         [-0.28573126],
#         [ 0.15372366],
#         [-0.04086896],
#         [ 0.05853916],
#         [ 0.05737615],
#         [-0.24741662],
#         [ 0.12445463],
#         [-0.18485038],
#         [ 0.10499084],
#         [ 0.24458718],
#         [-0.14616306],
#         [-0.2538912 ],
#         [ 0.09390706],
#         [-0.02055226],
#         [-0.00801404],
#         [ 0.0792046 ],
#         [-0.09219822],
#         [-0.01899626],
#         [ 0.08783438],
#         [ 0.22558732],
#         [-0.00193233],
#         [ 0.06630847],
#         [ 0.10341585],
#         [ 0.11157021],
#         [ 0.3611446 ],
#         [-0.12167346],
#         [ 0.24182914],
#         [-0.01294384],
#         [ 0.09227309],
#         [-0.02947096],
#         [ 0.2572458 ]], dtype=float32),
#  array([1.9148378], dtype=float32)]

# %%
# Step 2: Helper Functions
# Function to decode reviews
def decode_review(encoded_review):
    return ' '.join([reverse_word_index.get(i - 3, '?') for i in encoded_review])

# Function to preprocess user input
def preprocess_text(text):
    words = text.lower().split()
    encoded_review = [word_index.get(word, 2) + 3 for word in words]
    padded_review = sequence.pad_sequences([encoded_review], maxlen=500)
    return padded_review

# %%
### Prediction  function

def predict_sentiment(review):
    preprocessed_input=preprocess_text(review)

    prediction=model.predict(preprocessed_input)

    sentiment = 'Positive' if prediction[0][0] > 0.5 else 'Negative'
    
    return sentiment, prediction[0][0]

# %%
# Step 4: User Input and Prediction
# Example review for prediction
example_review = "This movie was fantastic! The acting was great and the plot was thrilling."

sentiment,score=predict_sentiment(example_review)

print(f'Review: {example_review}')
print(f'Sentiment: {sentiment}')
print(f'Prediction Score: {score}')
# Out:
# 1/1 [==============================] - 0s 196ms/step
# Review: This movie was fantastic! The acting was great and the plot was thrilling.
# Sentiment: Positive
# Prediction Score: 0.8114995360374451
